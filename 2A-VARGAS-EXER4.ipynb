# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # **1. DATA EXPLORATION**

# %%
data_path = "Lesson_4_student_grades_dataset.csv"
dataset = pd.read_csv(data_path)

statistics = dataset.describe()

x = dataset['Hours_of_Study']
x1 = dataset['Attendance_Percentage']
x2 = dataset['Previous_Exam_Scores']
x3 = dataset['Extracurricular_Activities']
x4 = dataset['Travel_Time_to_School']
y = dataset['Grades']

print(dataset.isnull().sum())

# %% [markdown]
# Discuss the potential impact of each feature on student grades.
#
# > **Hours of Study**: If the student spend more time studying, the student would get higher grades because he/she would have more time understanding the lessons.
#
# > **Attendance Percentage**: If the student have higher attendance percentage, he/she would participate in more activities and discussions resulting to higher grades.
#
# > **Previous Exam Scores**: If the student got a good exam score, the student would have a better grade because the student understood the lessons.
#
# > **Extracurricular Activities**: Extracurricular activities could either benefit the student by enhancing his/her time management or could either be a distraction to the students studies.
#
# > **Time Travel to School**: Less travel time for the student means more time for studying and less stress for the students academics.

# %% [markdown]
# # **2. DATA PREPROCESSING**

# %%
# no missing data

# %% [markdown]
# Discuss the importance of normalizing or standardizing numerical features.
#
# >

# %% [markdown]
# # **3. TRAIN-TEST SPLIT**

# %%
x = dataset.drop('Grades', axis = 1)
y = dataset['Grades']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # **4. LINEAR REGRESSION MODEL**

# %%
model = LinearRegression()

# %% [markdown]
# Discuss the interpretation of coefficients in the context of student grades.
#
# >

# %% [markdown]
# # **5. MODEL TRAINING**

# %%
model.fit(X_train,y_train)

# %% [markdown]
# # **6. PREDICTIONS AND EVALUATION**

# %%
new_data = np.array([[5,90,80,1,30]])
prediction = model.predict(new_data)

print(f"Predicted Grade: {prediction[0]}")

# %% [markdown]
# # **7. FEATURE IMPORTANCE ANALYSIS**

# %% [markdown]
# # **8. DISCUSSION**

# %% [markdown]
# Facilitate a discussion on the factors that seem to have the most significant impact on student grades.
#
# > The factors that have the most significant impact on the students grades are the hours of study and the previous exam scores. This is because they have direct connection with the students grades.
#
#
# Discuss any surprising findings or insights.
#
# > One surprising insight I discovered is that the attendance percentage is not really that influential to getting good grades. This is because not all students with high attendance percentage could have high scores and attending a class does not mean the student spends time studying.

# %% [markdown]
# # **9. SCENARIO EXTENSION**

# %% [markdown]
# Discuss additional features or scenarios that might influence student grades.
#
# > Some additional features that might influence the students grades are financial status, access to educational resources, family support, and more. These examples could also impact the studies of the student even if it happens outside the school setting.

# %% [markdown]
# # **10. REFLECTION**

# %% [markdown]
# Reflect on the challenges encountered, the significance of different features, and the potential real-world applications of the model.
#
# > The challenges encountered
